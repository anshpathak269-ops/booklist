# %% [markdown]
# <a href="https://colab.research.google.com/github/anshpathak269-ops/booklist/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {
    "Experience":[1,2,3,4,5],
    "Salary":[20000,40000,60000,80000,100000]

}
df = pd.DataFrame(data)
X = df[["Experience"]]
Y = df["Salary"]
print(X)
print(Y)
# Out:
#    Experience
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5
# 0     20000
# 1     40000
# 2     60000
# 3     80000
# 4    100000
# Name: Salary, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import pandas as pd

data = {
    "Experience": [1, 2, 3, 4, 5],
    "Salary": [20000, 40000, 60000, 80000, 100000]
}

df = pd.DataFrame(data)
X = df[["Experience"]]
Y = df["Salary"]

X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42
)

model = LinearRegression()
model.fit(X_train, Y_train)

prediction = model.predict([[6]])
print("Predicted Salary", prediction)
# Out:
# Predicted Salary [75000.]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import pandas as pd

data = {
    "Hours": [1, 2, 3, 4, 5],
    "Scores": [20, 40, 60, 80, 100]
}

df = pd.DataFrame(data)
x = df[["Hours"]]
y = df["Scores"]

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

model = LinearRegression()
model.fit(x_train, y_train)

prediction = model.predict([[6]])
print("Predicted Score", prediction)
# Out:
# Predicted Score [120.]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression

data = {
  "Temperature": [35, 25, 10, 22, 40],
    "GoOutside":   [0,  1,  0,  1,  0]
}

df = pd.DataFrame(data)
x = df[["Temperature"]]
y = df["GoOutside"]

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)
model = LogisticRegression()
model.fit(x_train, y_train)
prediction = model.predict([[10]])
print("Predicted Score", prediction)
# Out:
# Predicted Score [0]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

data = {
    "Hours": [1, 2, 3, 4, 5, 6, 7, 8],
    "Result": [0, 0, 1, 1, 1, 0, 0, 1]
}
df = pd.DataFrame(data)
X = df[["Hours"]]
Y = df["Result"]

X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y,
    test_size=0.2,
    random_state=42
)

model = KNeighborsClassifier(n_neighbors=3)
model.fit(X_train, Y_train)
prediction = model.predict(X_test)
accuracy = accuracy_score(Y_test, prediction)
print("Accuracy:", accuracy)
print("Prediction:", prediction)
# Out:
# Accuracy: 0.0
# Prediction: [1 1]
